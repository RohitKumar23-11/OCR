# %%
    from google.colab import drive
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# ===============================
# Colab: PaddleOCR Text Recognition
# ===============================

# 1. Setup Environment
#!pip install paddlepaddle-gpu==2.5.2
# !pip install paddlepaddle-gpu
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# %cd PaddleOCR
# !pip install -r requirements.txt

# 2. Download ICDAR2015 recognition subset (skip SSL check)
# !wget --no-check-certificate -nc https://datasets.cvc.uab.cat/icdar2015/cropped_recognition_samples.zip
# !unzip -qo cropped_recognition_samples.zip -d ./train_data/icdar2015_rec

# 3. Create label file (img_path \t transcription)
import glob, os
from pathlib import Path

os.makedirs("./train_data/icdar2015_rec", exist_ok=True)

with open("./train_data/icdar2015_rec/train_label.txt", "w", encoding="utf-8") as f:
    for img in glob.glob("./train_data/icdar2015_rec/train_images/*.jpg"):
        text = Path(img).stem.split("_")[-1]  # assume filename encodes label
        f.write(f"{img}\t{text}\n")

# 4. Train CRNN Recognition (Lightweight)
# !python tools/train.py -c configs/rec/rec_icdar15_crnn_lightweight.yml -o Global.pretrained_model=None

# 5. Evaluate
# !python tools/eval.py -c configs/rec/rec_icdar15_crnn_lightweight.yml -o Global.checkpoints=output/rec_crnn/best_accuracy

# 6. Inference Example
# !python tools/infer_rec.py -c configs/rec/rec_icdar15_crnn_lightweight.yml \
    -o Global.checkpoints=output/rec_crnn/best_accuracy \
    Global.infer_img=doc/imgs_words_en/word_1.png
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# ...
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 284199, done.
# remote: Counting objects: 100% (2613/2613), done.
# remote: Compressing objects: 100% (512/512), done.
# remote: Total 284199 (delta 2371), reused 2101 (delta 2101), pack-reused 281586 (from 4)
# Receiving objects: 100% (284199/284199), 1.50 GiB | 36.35 MiB/s, done.
# Resolving deltas: 100% (224562/224562), done.
# /content/PaddleOCR
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 14.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.0/303.0 kB 26.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 66.5 MB/s eta 0:00:00
# ...

# %%
# 1. Install PaddleOCR
# !pip install paddlepaddle-gpu
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# %cd PaddleOCR
# !pip install -r requirements.txt

# 2. Download ICDAR2015 dataset (from PaddleOCR Baidu / alternative mirrors)
# !wget -nc https://paddleocr.bj.bcebos.com/dataset/icdar2015_rec.zip
# !unzip -qo icdar2015_rec.zip -d ./train_data/

# 3. Create label file
import glob, os
from pathlib import Path

os.makedirs("./train_data/icdar2015_rec", exist_ok=True)

with open("./train_data/icdar2015_rec/train_label.txt", "w", encoding="utf-8") as f:
    for img in glob.glob("./train_data/icdar2015_rec/train_images/*.jpg"):
        text = Path(img).stem.split("_")[-1]  # adjust depending on filenames
        f.write(f"{img}\t{text}\n")

# 4. Train CRNN Recognition
# !python tools/train.py \
    -c configs/rec/rec_icdar15_train.yml \
    -o Global.pretrained_model=None

# 5. Evaluate
# !python tools/eval.py \
    -c configs/rec/rec_icdar15_train.yml \
    -o Global.checkpoints=output/rec_icdar15/best_accuracy

# 6. Inference Example
# !python tools/infer_rec.py \
    -c configs/rec/rec_icdar15_train.yml \
    -o Global.checkpoints=output/rec_icdar15/best_accuracy \
    Global.infer_img=doc/imgs_words_en/word_1.png
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.9/758.9 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opt-einsum
#     Found existing installation: opt_einsum 3.4.0
#     Uninstalling opt_einsum-3.4.0:
#       Successfully uninstalled opt_einsum-3.4.0
# ...
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 284199, done.
# remote: Counting objects: 100% (2611/2611), done.
# remote: Compressing objects: 100% (511/511), done.
# remote: Total 284199 (delta 2370), reused 2100 (delta 2100), pack-reused 281588 (from 4)
# Receiving objects: 100% (284199/284199), 1.50 GiB | 30.61 MiB/s, done.
# Resolving deltas: 100% (224424/224424), done.
# /content/PaddleOCR
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 303.0/303.0 kB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 60.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
